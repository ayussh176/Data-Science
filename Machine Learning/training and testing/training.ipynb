# %%
import pandas as pd

# %%
df = pd.read_csv('carprices.csv')
df
# Out:
#     Mileage  Age(yrs)  Sell_Price
# 0     69000         6       18000
# 1     35000         3       34000
# 2     57000         5       26100
# 3     22500         2       40000
# 4     46000         4       31500
# 5     59000         5       26750
# 6     52000         5       32000
# 7     72000         6       19300
# 8     91000         8       12000
# 9     67000         6       22000
# 10    83000         7       18700
# 11    79000         7       19500
# 12    59000         5       26000
# 13    58780         4       27500
# 14    82450         7       19400
# 15    25400         3       35000
# 16    28000         2       35500
# 17    69000         5       19700
# 18    87600         8       12800
# 19    52000         5       28200

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
plt.scatter(df['Mileage'], df['Sell_Price'])
plt.show()

# %%
X = df[['Mileage', 'Age(yrs)']]
y = df['Sell_Price']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
len(X_train)
# Out:
# 16

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([15115.14615586, 30613.99203411, 16374.73341138, 39087.71505251])

# %%
y_test
# Out:
# 18    12800
# 4     31500
# 10    18700
# 15    35000
# Name: Sell_Price, dtype: int64

# %%
model.score(X_test, y_test)
# Out:
# 0.9143028961813935
