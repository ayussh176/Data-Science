# %%
import pandas as pd
df = pd.read_csv('stocks.csv')
df
# Out:
#   Company Name  Price  Earnings Per Share  Book Value
# 0     Reliance   1467                  66         653
# 1   Tata Steel    391                  89         572

# %%
a=df['Book Value'].max()
print(a)
# Out:
# 653

# %%
b = df['Book Value'].mean()
print(b)
# Out:
# 612.5

# %%
wr = pd.read_csv('weather.csv')
wr
# Out:
#           Date  Month  Week  Year                      City StationCode  \
# 0   01-01-2016      1     3  2016                Birmingham         BHM
# 1   02-01-2016      1     3  2016                Huntsville         HSV
# 2   03-01-2016      1     3  2016                    Mobile         MOB
# 3   04-01-2016      1     3  2016                Montgomery         MGM
# 4   05-01-2016      1     3  2016                 Anchorage         ANC
# 5   06-01-2016      1     3  2016                   Annette         ANN
# 6   07-01-2016      1     3  2016                    Bethel         BET
# 7   08-01-2016      1     3  2016                   Bettles         BTT
# 8   09-01-2016      1     3  2016                  Cold Bay         CDB
# 9   10-01-2016      1     3  2016                   Cordova         CDV
# 10  11-01-2016      1     3  2016  Delta Junction/Ft Greely         BIG
# 11  12-01-2016      1     3  2016                 Fairbanks         FAI
# ...

# %%
wr.shape #this is in the form of tuple you can save it using variables
r,w = wr.shape
print("rows are:",r)
print("columns are:",w)
# Out:
# rows are: 34
# columns are: 13

# %%
wr.head()
# Out:
#          Date  Month  Week  Year        City StationCode        Location  \
# 0  01-01-2016      1     3  2016  Birmingham         BHM  Birmingham, AL
# 1  02-01-2016      1     3  2016  Huntsville         HSV  Huntsville, AL
# 2  03-01-2016      1     3  2016      Mobile         MOB      Mobile, AL
# 3  04-01-2016      1     3  2016  Montgomery         MGM  Montgomery, AL
# 4  05-01-2016      1     3  2016   Anchorage         ANC   Anchorage, AK
#
#      State  Avg Temp  MaxTemp  MinTemp  WindDirection  WindSpeed
# 0  Alabama        39       46       32             33       4.33
# 1  Alabama        39       47       31             32       3.86
# 2  Alabama        46       51       41             35       9.73
# 3  Alabama        45       52       38             32       6.86
# 4   Alaska        34       38       29             19       7.80

# %%
wr.tail()
# Out:
#           Date  Month  Week  Year                City StationCode  \
# 29  30-01-2016      1     3  2016             Skagway         SGY
# 30  31-01-2016      1     3  2016      St Paul Island         SNP
# 31  01-02-2016      1     3  2016           Talkeetna         TKA
# 32  02-02-2016      1     3  2016              Tanana         TAL
# 33  03-02-2016      1     3  2016  Utqiagvik (Barrow)         BRW
#
#                   Location   State  Avg Temp  MaxTemp  MinTemp  WindDirection  \
# 29             Skagway, AK  Alaska        38       42       33             14
# 30      St Paul Island, AK  Alaska        32       35       29             22
# 31           Talkeetna, AK  Alaska        32       39       23              2
# 32              Tanana, AK  Alaska        21       29       13              8
# 33  Utqiagvik (Barrow), AK  Alaska         6        9        2              6
#
#     WindSpeed
# 29       5.20
# 30       9.03
# 31       4.93
# 32       3.83
# 33      13.76

# %%
wr[2:5]
# Out:
#          Date  Month  Week  Year        City StationCode        Location  \
# 2  03-01-2016      1     3  2016      Mobile         MOB      Mobile, AL
# 3  04-01-2016      1     3  2016  Montgomery         MGM  Montgomery, AL
# 4  05-01-2016      1     3  2016   Anchorage         ANC   Anchorage, AK
#
#      State  Avg Temp  MaxTemp  MinTemp  WindDirection  WindSpeed
# 2  Alabama        46       51       41             35       9.73
# 3  Alabama        45       52       38             32       6.86
# 4   Alaska        34       38       29             19       7.80

# %%
wr.columns
# Out:
# Index(['Date', 'Month', 'Week', 'Year', 'City', 'StationCode', 'Location',
#        'State', 'Avg Temp', 'MaxTemp', 'MinTemp', 'WindDirection',
#        'WindSpeed'],
#       dtype='object')

# %%
wr.Date
# Out:
# 0     01-01-2016
# 1     02-01-2016
# 2     03-01-2016
# 3     04-01-2016
# 4     05-01-2016
# 5     06-01-2016
# 6     07-01-2016
# 7     08-01-2016
# 8     09-01-2016
# 9     10-01-2016
# 10    11-01-2016
# 11    12-01-2016
# 12    13-01-2016
# 13    14-01-2016
# 14    15-01-2016
# 15    16-01-2016
# 16    17-01-2016
# 17    18-01-2016
# 18    19-01-2016
# 19    20-01-2016
# 20    21-01-2016
# 21    22-01-2016
# 22    23-01-2016
# 23    24-01-2016
# 24    25-01-2016
# 25    26-01-2016
# 26    27-01-2016
# 27    28-01-2016
# 28    29-01-2016
# 29    30-01-2016
# 30    31-01-2016
# 31    01-02-2016
# 32    02-02-2016
# 33    03-02-2016
# Name: Date, dtype: object

# %%
wr['Avg Temp']
# Out:
# 0     39
# 1     39
# 2     46
# 3     45
# 4     34
# 5     38
# 6     30
# 7     22
# 8     34
# 9     38
# 10    31
# 11    14
# 12    27
# 13    39
# 14    40
# 15    36
# 16    34
# 17    37
# 18    39
# 19    40
# 20    27
# 21    30
# 22    29
# 23     0
# 24    37
# 25    60
# 26    60
# 27    60
# 28    43
# 29    38
# 30    32
# 31    32
# 32    21
# 33     6
# Name: Avg Temp, dtype: int64

# %%
#to print only few columns we do so
wr[['City','StationCode']]
# Out:
#                         City StationCode
# 0                 Birmingham         BHM
# 1                 Huntsville         HSV
# 2                     Mobile         MOB
# 3                 Montgomery         MGM
# 4                  Anchorage         ANC
# 5                    Annette         ANN
# 6                     Bethel         BET
# 7                    Bettles         BTT
# 8                   Cold Bay         CDB
# 9                    Cordova         CDV
# 10  Delta Junction/Ft Greely         BIG
# 11                 Fairbanks         FAI
# 12                   Gulkana         GKN
# 13                     Homer         HOM
# 14                   Iliamna         ILI
# 15                    Juneau         JNU
# 16                     Kenai         ENA
# 17                 Ketchikan         KTN
# 18               King Salmon         AKN
# 19                    Kodiak         ADQ
# 20                  Kotzebue         OTZ
# 21                  Mc Grath         MCG
# ...

# %%
a=wr['WindSpeed'].max()
print(a)
# Out:
# 21.8

# %%
wr.describe()
# Out:
#        Month  Week    Year   Avg Temp    MaxTemp    MinTemp  WindDirection  \
# count   34.0  34.0    34.0  34.000000  34.000000  34.000000      34.000000
# mean     1.0   3.0  2016.0  34.617647  39.647059  29.088235      13.205882
# std      0.0   0.0     0.0  12.825199  11.178666  14.878025       9.367188
# min      1.0   3.0  2016.0   0.000000   8.000000  -9.000000       0.000000
# 25%      1.0   3.0  2016.0  30.000000  35.250000  23.000000       8.000000
# 50%      1.0   3.0  2016.0  36.500000  40.500000  31.000000      10.500000
# 75%      1.0   3.0  2016.0  39.000000  43.750000  35.000000      18.750000
# max      1.0   3.0  2016.0  60.000000  60.000000  60.000000      35.000000
#
#        WindSpeed
# count    34.0000
# mean      8.6850
# std       5.7454
# min       0.0000
# 25%       3.9775
# 50%       8.8650
# 75%      11.2600
# max      21.8000

# %%
#here i have put the essential data in another data frame 
jd = wr[['Avg Temp','MaxTemp','MinTemp','WindDirection','WindSpeed']]
jd
# Out:
#     Avg Temp  MaxTemp  MinTemp  WindDirection  WindSpeed
# 0         39       46       32             33       4.33
# 1         39       47       31             32       3.86
# 2         46       51       41             35       9.73
# 3         45       52       38             32       6.86
# 4         34       38       29             19       7.80
# 5         38       44       31              9       8.70
# 6         30       36       24              9      16.46
# 7         22       32        9              2       3.10
# 8         34       36       31             20       9.10
# 9         38       43       33              9       9.76
# 10        31       39       23             14      17.90
# 11        14       30        4              2       2.20
# 12        27       34       19             14       8.23
# 13        39       42       35              9      11.26
# 14        40       42       37              9      19.76
# ...

# %%
jd.describe()
# Out:
#         Avg Temp    MaxTemp    MinTemp  WindDirection  WindSpeed
# count  34.000000  34.000000  34.000000      34.000000    34.0000
# mean   34.617647  39.647059  29.088235      13.205882     8.6850
# std    12.825199  11.178666  14.878025       9.367188     5.7454
# min     0.000000   8.000000  -9.000000       0.000000     0.0000
# 25%    30.000000  35.250000  23.000000       8.000000     3.9775
# 50%    36.500000  40.500000  31.000000      10.500000     8.8650
# 75%    39.000000  43.750000  35.000000      18.750000    11.2600
# max    60.000000  60.000000  60.000000      35.000000    21.8000

# %%
#this is conditional selection of rows 
wr[wr.WindSpeed>=15]
# Out:
#           Date  Month  Week  Year                      City StationCode  \
# 6   07-01-2016      1     3  2016                    Bethel         BET
# 10  11-01-2016      1     3  2016  Delta Junction/Ft Greely         BIG
# 14  15-01-2016      1     3  2016                   Iliamna         ILI
# 18  19-01-2016      1     3  2016               King Salmon         AKN
# 19  20-01-2016      1     3  2016                    Kodiak         ADQ
#
#                         Location   State  Avg Temp  MaxTemp  MinTemp  \
# 6                     Bethel, AK  Alaska        30       36       24
# 10  Delta Junction/Ft Greely, AK  Alaska        31       39       23
# 14                   Iliamna, AK  Alaska        40       42       37
# 18               King Salmon, AK  Alaska        39       42       35
# 19                    Kodiak, AK  Alaska        40       42       36
#
#     WindDirection  WindSpeed
# 6               9      16.46
# 10             14      17.90
# ...

# %%
#you can also use several fuction to define conndition 
wr[wr.WindSpeed== wr['WindSpeed'].max()]
# Out:
#           Date  Month  Week  Year    City StationCode    Location   State  \
# 19  20-01-2016      1     3  2016  Kodiak         ADQ  Kodiak, AK  Alaska
#
#     Avg Temp  MaxTemp  MinTemp  WindDirection  WindSpeed
# 19        40       42       36             11       21.8

# %%
wr[['Date','MaxTemp']][wr.MaxTemp==wr.MaxTemp.max()]
# Out:
#           Date  MaxTemp
# 25  26-01-2016       60
# 26  27-01-2016       60
# 27  28-01-2016       60

# %%
wr.index
# Out:
# RangeIndex(start=0, stop=34, step=1)

# %%
wr.set_index('Date',inplace=True)
wr
# Out:
#             Month  Week  Year                      City StationCode  \
# Date
# 01-01-2016      1     3  2016                Birmingham         BHM
# 02-01-2016      1     3  2016                Huntsville         HSV
# 03-01-2016      1     3  2016                    Mobile         MOB
# 04-01-2016      1     3  2016                Montgomery         MGM
# 05-01-2016      1     3  2016                 Anchorage         ANC
# 06-01-2016      1     3  2016                   Annette         ANN
# 07-01-2016      1     3  2016                    Bethel         BET
# 08-01-2016      1     3  2016                   Bettles         BTT
# 09-01-2016      1     3  2016                  Cold Bay         CDB
# 10-01-2016      1     3  2016                   Cordova         CDV
# 11-01-2016      1     3  2016  Delta Junction/Ft Greely         BIG
# 12-01-2016      1     3  2016                 Fairbanks         FAI
# 13-01-2016      1     3  2016                   Gulkana         GKN
# ...

# %%
#this is use to locate the row with that index
wr.loc['02-01-2016']
# Out:
# Month                         1
# Week                          3
# Year                       2016
# City                 Huntsville
# StationCode                 HSV
# Location         Huntsville, AL
# State                   Alabama
# Avg Temp                     39
# MaxTemp                      47
# MinTemp                      31
# WindDirection                32
# WindSpeed                  3.86
# Name: 02-01-2016, dtype: object

# %%
wr.reset_index(inplace=True)
